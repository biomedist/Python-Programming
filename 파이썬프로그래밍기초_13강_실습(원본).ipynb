# %% [markdown]
# <a href="https://colab.research.google.com/github/biomedist/Python-Programming/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_13%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 13강 실전 프로젝트 1 실습

# %% [markdown]
# ### 텍스트 데이터 인사이트 분석기

# %% [markdown]
# **데이터 전처리(데이터 변환 및 불용어 필터링)**

# %%
# 특수문자 목록
PUNCTUATIONS = ".,!?\"':;()-"

def clean_text(fp):
    text = ""

    for line in fp:
        # 소문자 변환
        line = line.lower()
# PUNCTUATION에 해당하는 문자가 line에 있으면 공백으로 대체(replace)
        for char in PUNCTUATIONS:
            line = line.replace(char, "")

        text += " " + line
# 정제된 text반환
    return text

# %% [markdown]
# **데이터 분석(단어 카운트)**

# %%
# 불용어 집합
STOPWORDS = {"a", "the", "is", "of", "in", "to", "and", "i", "it", "that", \
             "this", "my", "was", "for", "as", "but", "so", "be", "he", \
             "me", "his", "him", "she", "her", "you", "your", "we", "our", "us", \
             "on", "were", "been", "are"}

def count_words(text):
    # text내의 문자들을 공백기준으로 쪼개기(split)
    words = text.split();
    counts = {}

    for word in words:
        word.strip()

        if word in STOPWORDS:
            continue
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
# 딕셔너리 counts에서 word값을 찾아보고, 있으면 그 값(value)을 가져오고, 없으면 0을 가져오라는 의미
        counts[word] = counts.get(word, 0) + 1

    return counts
# Out:
#   File "/tmp/ipykernel_17828/4138800683.py", line 7
#     def count_words(text):
#                           ^
# SyntaxError: incomplete input

# %% [markdown]
# **데이터 시각화(텍스트 시각화)**

# %%
def get_sorted_list(counts_dict):

def print_save_graph(filename, sorted_list, tops = 10):

# %% [markdown]
# **결과 파일 저장 및 파일 닫기**

# %%
##CWD, 파일목록 출력하고 파일이름 입력 받기
import os

print("현재 작업 디렉토리: ",os.getcwd())
print("현재 디렉토리 파일목록:\n")
print(os.listdir(os.getcwd()))


##파일_변수 생성
filename = input("분석할 파일이름을 입력하세요.")

print(filename)

da_fp = open(filename, "r")
text = clean_text(da_fp)
# print(text)

w_dict = count_words(text)

#count_list = get_sorted_list(w_dict)

#print_save_graph("result.txt", count_list, 200)

#da_fp.close()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#       very room which our innocent friend now devotes to his museum so at
#       last we get a link you see
#
#       and the next link
#
#       well we must go now and look for that
#
#       he took a revolver from the drawer and handed it to me
#
#       i have my old favourite with me if our wild west friend tries to
#       live up to his nickname we must be ready for him ill give you an
#       hour for a siesta watson and then i think it will be time for our
#       ryder street adventure
#
#       it was just four oclock when we reached the curious apartment of
#       nathan garrideb mrs saunders the caretaker was about to leave
#       but she had no hesitation in admitting us for the door shut with a
#       spring lock and holmes promised to see that all was safe before we
#       left shortly afterwards the outer door closed her bonnet passed the
#       bow window and we knew that we were alone in the lower floor of the
# ...
